# %% [markdown]
# ### Exercise 5: Subplot Layout

# %%
# TASK: Create a 2x2 subplot layout.
# Plot a line chart in the first subplot, a bar chart in the second, a scatter plot in the third, and a pie chart in the fourth.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
x = np.arange(0, 10)
y = x ** 2
categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 9]
scatter_x = [1, 2, 3, 4, 5]
scatter_y = [2, 4, 6, 8, 10]
pie_labels = ['Python', 'Java', 'C++', 'JavaScript']
pie_sizes = [40, 25, 20, 15]

# Create a 2x2 subplot layout
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Subplot 1: Line chart
axs[0, 0].plot(x, y, color='blue')
axs[0, 0].set_title('Line Chart')
axs[0, 0].set_xlabel('X Values')
axs[0, 0].set_ylabel('Y = X Squared')

# Subplot 2: Bar chart
axs[0, 1].bar(categories, values, color=['red', 'blue', 'green', 'orange'])
axs[0, 1].set_title('Bar Chart')
axs[0, 1].set_xlabel('Categories')
axs[0, 1].set_ylabel('Values')

# Subplot 3: Scatter plot
axs[1, 0].scatter(scatter_x, scatter_y, color='purple')
for i in range(len(scatter_x)):
    axs[1, 0].text(scatter_x[i] + 0.1, scatter_y[i], f'({scatter_x[i]}, {scatter_y[i]})', fontsize=9)
    axs[1, 0].set_title('Scatter Plot with Annotations')

    # Subplot 4: Pie chart
    axs[1, 1].pie(pie_sizes, labels=pie_labels, autopct='%1.1f%%', startangle=140)
    axs[1, 1].set_title('Pie Chart')

    # Adjust layout to prevent overlap
    plt.tight_layout()

    # Display the plot
    plt.show()
