# %% [markdown]
# ### Exercise 2: Bar Plot with Colors

# %%
# TASK: Create a bar plot with the following data: categories = ['A', 'B', 'C', 'D'] and values = [5, 7, 3, 9].
# Use different colors for each bar and add a title to the plot.
import matplotlib.pyplot as plt
import numpy as np

# Define data
x = np.arange(0, 11)           # x values from 0 to 10
y = x ** 2                     # y values as square of x

# Create plot
plt.figure(figsize=(8, 5))     # Optional: adjust figure size
plt.plot(x, y, marker='o', color='blue', linestyle='-')

# Customize plot
plt.title('Square of Numbers from 0 to 10')
plt.xlabel('X Values')
plt.ylabel('Y = X Squared')
8plt.plot(x, y, marker='o', color='blue', linestyle='-')

# Customize plot
plt.title('Square of Numbers from 0 to 10')
plt.xlabel('X Values')



plt.xlabel('X Values')

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 9]
colors = ['red', 'blue', 'green', 'orange']  # One color per bar

# Create bar plot
plt.figure(figsize=(7, 5))
plt.bar(categories, values, color=colors)

# Add title and labels
plt.title('Bar Plot of Categories')
plt.xlabel('Categories')
plt.ylabel('Values')

# Show plot
plt.show()
